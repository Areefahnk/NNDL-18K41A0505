# %% [markdown]
# <a href="https://colab.research.google.com/github/Areefahnk/NNDL-18K41A0505/blob/main/Assignment_02_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find Global Minima Point
#
# **GRADIENT DESCENT ALGORITHM - MULTI VARIABLES**
#
# **Implementing with Python Programming - By AREEFA (18K41A0505)**

# %% [markdown]
# ![asg2.PNG](data:image/png;base64,...)

# %%
import sympy as sym
from sympy import *

# %%
import random

# %%
#step 1
#initaialize
X = random.randint(1,5)
Y = random.randint(1,5)
print("Random values of X = {}".format(X)+" Y = {}".format(Y))
n = 0.01
epochs = 150
iter = 1
x=0
x = sym.Symbol('x')
y = sym.Symbol('y')
print("Customize the funtion f = a*x**i+b*y**j+c")
a = int(input('Enter coefficient of x (if exists or else 0) a:'))
i = int(input('Enter the power of x (if exists or else 0) i:'))
b = int(input('Enter coefficient of y (if exists or else 0) b:'))
j = int(input('Enter the power of y (if exists or else 0) j:'))
c = int(input('Enter constants if exist c:'))
f = a*x**i+b*y**j+c
print("INPUT FUNCTION f(x,y): {}".format(f))
print("------------------------------------------------------------------------------")
print("Step 1: Initialization done and function is {}".format(f))
while 1:
  print("Iteration number: {}".format(iter))
  #step 2
  #Calculate Gradient/slope/firstorderderivative
  #derivative wrto x
  dfx = sym.diff(f,x)
  dfy = sym.diff(f,y) #derivative wrto y
  slopex = dfx.subs(x,X) #after substitution of X in slope (dfx)
  slopey = dfy.subs(y,Y) #after substitution of Y in slope (dfy)
  print("Step 2: slopex = {}".format(slopex)+" slopey = {}".format(slopey))
  #step 3 - find change in variables values - we get step length
  delta_X = -(n)*slopex
  delta_Y = -(n)*slopey
  print("Step 3: delta_X {}".format(delta_X)+" delta_Y {}".format(delta_Y))
  #step 4: updating variable value
  X = X+delta_X
  Y = Y+delta_Y
  print("Step 4: Updated Value X = {}".format(X)+" Y = {}".format(Y))

  resf = f.subs(x,X)
  res = resf.subs(y,Y)
  print("Checking for the result value of the function f(updated_X,updated_Y) = {}".format(res))

  #step 5: update iter
  print("step 5: Update iteration")
  iter = iter+1
  if(iter>epochs):
    break;
  else:
    print("Goto step 2")
  print("-------------------------------------------------------------------")

print("---------------------------------------------------------------------------")
print("Global Minima point obtained: after rounding to two values after decimal point")
print("X: ",round(X,2))
print("Y: ",round(Y,2))
optimalres = f.subs(x,X)
optimalfinal = optimalres.subs(y,Y)
print("Optimal function value: ",round(optimalfinal,2))
# Out:
# Random values of X = 4 Y = 3
# Customize the funtion f = a*x**i+b*y**j+c
# Enter coefficient of x (if exists or else 0) a:1
# Enter the power of x (if exists or else 0) i:2
# Enter coefficient of y (if exists or else 0) b:1
# Enter the power of y (if exists or else 0) j:2
# Enter constants if exist c:10
# INPUT FUNCTION f(x,y): x**2 + y**2 + 10
# ------------------------------------------------------------------------------
# Step 1: Initialization done and function is x**2 + y**2 + 10
# Iteration number: 1
# Step 2: slopex = 8 slopey = 6
# Step 3: delta_X -0.0800000000000000 delta_Y -0.0600000000000000
# Step 4: Updated Value X = 3.92000000000000 Y = 2.94000000000000
# Checking for the result value of the function f(updated_X,updated_Y) = 34.0100000000000
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 2
# Step 2: slopex = 7.84000000000000 slopey = 5.88000000000000
# Step 3: delta_X -0.0784000000000000 delta_Y -0.0588000000000000
# Step 4: Updated Value X = 3.84160000000000 Y = 2.88120000000000
# Checking for the result value of the function f(updated_X,updated_Y) = 33.0592040000000
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 3
# Step 2: slopex = 7.68320000000000 slopey = 5.76240000000000
# Step 3: delta_X -0.0768320000000000 delta_Y -0.0576240000000000
# Step 4: Updated Value X = 3.76476800000000 Y = 2.82357600000000
# Checking for the result value of the function f(updated_X,updated_Y) = 32.1460595216000
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 4
# Step 2: slopex = 7.52953600000000 slopey = 5.64715200000000
# Step 3: delta_X -0.0752953600000000 delta_Y -0.0564715200000000
# Step 4: Updated Value X = 3.68947264000000 Y = 2.76710448000000
# Checking for the result value of the function f(updated_X,updated_Y) = 31.2690755645446
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 5
# Step 2: slopex = 7.37894528000000 slopey = 5.53420896000000
# Step 3: delta_X -0.0737894528000000 delta_Y -0.0553420896000000
# Step 4: Updated Value X = 3.61568318720000 Y = 2.71176239040000
# Checking for the result value of the function f(updated_X,updated_Y) = 30.4268201721887
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 6
# Step 2: slopex = 7.23136637440000 slopey = 5.42352478080000
# Step 3: delta_X -0.0723136637440000 delta_Y -0.0542352478080000
# Step 4: Updated Value X = 3.54336952345600 Y = 2.65752714259200
# Checking for the result value of the function f(updated_X,updated_Y) = 29.6179180933700
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 7
# Step 2: slopex = 7.08673904691200 slopey = 5.31505428518400
# Step 3: delta_X -0.0708673904691200 delta_Y -0.0531505428518400
# Step 4: Updated Value X = 3.47250213298688 Y = 2.60437659974016
# Checking for the result value of the function f(updated_X,updated_Y) = 28.8410485368725
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 8
# Step 2: slopex = 6.94500426597376 slopey = 5.20875319948032
# Step 3: delta_X -0.0694500426597376 delta_Y -0.0520875319948032
# Step 4: Updated Value X = 3.40305209032714 Y = 2.55228906774536
# Checking for the result value of the function f(updated_X,updated_Y) = 28.0949430148124
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 9
# Step 2: slopex = 6.80610418065428 slopey = 5.10457813549071
# Step 3: delta_X -0.0680610418065428 delta_Y -0.0510457813549071
# Step 4: Updated Value X = 3.33499104852060 Y = 2.50124328639045
# Checking for the result value of the function f(updated_X,updated_Y) = 27.3783832714258
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 10
# Step 2: slopex = 6.66998209704120 slopey = 5.00248657278090
# Step 3: delta_X -0.0666998209704120 delta_Y -0.0500248657278090
# Step 4: Updated Value X = 3.26829122755019 Y = 2.45121842066264
# Checking for the result value of the function f(updated_X,updated_Y) = 26.6901992938774
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 11
# Step 2: slopex = 6.53658245510038 slopey = 4.90243684132528
# Step 3: delta_X -0.0653658245510038 delta_Y -0.0490243684132528
# Step 4: Updated Value X = 3.20292540299918 Y = 2.40219405224939
# Checking for the result value of the function f(updated_X,updated_Y) = 26.0292674018398
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 12
# Step 2: slopex = 6.40585080599837 slopey = 4.80438810449877
# Step 3: delta_X -0.0640585080599837 delta_Y -0.0480438810449877
# Step 4: Updated Value X = 3.13886689493920 Y = 2.35415017120440
# Checking for the result value of the function f(updated_X,updated_Y) = 25.3945084127270
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 13
# Step 2: slopex = 6.27773378987840 slopey = 4.70830034240880
# Step 3: delta_X -0.0627773378987840 delta_Y -0.0470830034240880
# Step 4: Updated Value X = 3.07608955704042 Y = 2.30706716778031
# Checking for the result value of the function f(updated_X,updated_Y) = 24.7848858795830
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 14
# Step 2: slopex = 6.15217911408083 slopey = 4.61413433556062
# Step 3: delta_X -0.0615217911408083 delta_Y -0.0461413433556062
# Step 4: Updated Value X = 3.01456776589961 Y = 2.26092582442471
# Checking for the result value of the function f(updated_X,updated_Y) = 24.1994043987515
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 15
# Step 2: slopex = 6.02913553179922 slopey = 4.52185164884941
# Step 3: delta_X -0.0602913553179922 delta_Y -0.0452185164884941
# Step 4: Updated Value X = 2.95427641058162 Y = 2.21570730793621
# Checking for the result value of the function f(updated_X,updated_Y) = 23.6371079845609
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 16
# Step 2: slopex = 5.90855282116323 slopey = 4.43141461587242
# Step 3: delta_X -0.0590855282116323 delta_Y -0.0443141461587242
# Step 4: Updated Value X = 2.89519088236998 Y = 2.17139316177749
# Checking for the result value of the function f(updated_X,updated_Y) = 23.0970785083723
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 17
# Step 2: slopex = 5.79038176473997 slopey = 4.34278632355497
# Step 3: delta_X -0.0579038176473997 delta_Y -0.0434278632355497
# Step 4: Updated Value X = 2.83728706472258 Y = 2.12796529854194
# Checking for the result value of the function f(updated_X,updated_Y) = 22.5784341994408
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 18
# Step 2: slopex = 5.67457412944517 slopey = 4.25593059708387
# Step 3: delta_X -0.0567457412944517 delta_Y -0.0425593059708387
# Step 4: Updated Value X = 2.78054132342813 Y = 2.08540599257110
# Checking for the result value of the function f(updated_X,updated_Y) = 22.0803282051429
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 19
# Step 2: slopex = 5.56108264685626 slopey = 4.17081198514220
# Step 3: delta_X -0.0556108264685626 delta_Y -0.0417081198514220
# Step 4: Updated Value X = 2.72493049695957 Y = 2.04369787271968
# Checking for the result value of the function f(updated_X,updated_Y) = 21.6019472082193
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 20
# Step 2: slopex = 5.44986099391914 slopey = 4.08739574543935
# Step 3: delta_X -0.0544986099391914 delta_Y -0.0408739574543935
# Step 4: Updated Value X = 2.67043188702038 Y = 2.00282391526528
# Checking for the result value of the function f(updated_X,updated_Y) = 21.1425100987738
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 21
# Step 2: slopex = 5.34086377404076 slopey = 4.00564783053057
# Step 3: delta_X -0.0534086377404076 delta_Y -0.0400564783053057
# Step 4: Updated Value X = 2.61702324927997 Y = 1.96276743695998
# Checking for the result value of the function f(updated_X,updated_Y) = 20.7012666988623
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 22
# Step 2: slopex = 5.23404649855994 slopey = 3.92553487391996
# Step 3: delta_X -0.0523404649855994 delta_Y -0.0392553487391996
# Step 4: Updated Value X = 2.56468278429437 Y = 1.92351208822078
# Checking for the result value of the function f(updated_X,updated_Y) = 20.2774965375874
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 23
# Step 2: slopex = 5.12936556858874 slopey = 3.84702417644156
# Step 3: delta_X -0.0512936556858874 delta_Y -0.0384702417644156
# Step 4: Updated Value X = 2.51338912860848 Y = 1.88504184645636
# Checking for the result value of the function f(updated_X,updated_Y) = 19.8705076746989
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 24
# Step 2: slopex = 5.02677825721697 slopey = 3.77008369291273
# Step 3: delta_X -0.0502677825721697 delta_Y -0.0377008369291272
# Step 4: Updated Value X = 2.46312134603631 Y = 1.84734100952724
# Checking for the result value of the function f(updated_X,updated_Y) = 19.4796355707808
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 25
# Step 2: slopex = 4.92624269207263 slopey = 3.69468201905447
# Step 3: delta_X -0.0492624269207263 delta_Y -0.0369468201905447
# Step 4: Updated Value X = 2.41385891911559 Y = 1.81039418933669
# Checking for the result value of the function f(updated_X,updated_Y) = 19.1042420021779
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 26
# Step 2: slopex = 4.82771783823117 slopey = 3.62078837867338
# Step 3: delta_X -0.0482771783823117 delta_Y -0.0362078837867338
# Step 4: Updated Value X = 2.36558174073328 Y = 1.77418630554996
# Checking for the result value of the function f(updated_X,updated_Y) = 18.7437140188917
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 27
# Step 2: slopex = 4.73116348146655 slopey = 3.54837261109991
# Step 3: delta_X -0.0473116348146655 delta_Y -0.0354837261109991
# Step 4: Updated Value X = 2.31827010591861 Y = 1.73870257943896
# Checking for the result value of the function f(updated_X,updated_Y) = 18.3974629437436
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 28
# Step 2: slopex = 4.63654021183722 slopey = 3.47740515887792
# Step 3: delta_X -0.0463654021183722 delta_Y -0.0347740515887792
# Step 4: Updated Value X = 2.27190470380024 Y = 1.70392852785018
# Checking for the result value of the function f(updated_X,updated_Y) = 18.0649234111713
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 29
# Step 2: slopex = 4.54380940760048 slopey = 3.40785705570036
# Step 3: delta_X -0.0454380940760048 delta_Y -0.0340785705570036
# Step 4: Updated Value X = 2.22646660972423 Y = 1.66984995729318
# Checking for the result value of the function f(updated_X,updated_Y) = 17.7455524440889
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 30
# Step 2: slopex = 4.45293321944847 slopey = 3.33969991458635
# Step 3: delta_X -0.0445293321944847 delta_Y -0.0333969991458635
# Step 4: Updated Value X = 2.18193727752975 Y = 1.63645295814731
# Checking for the result value of the function f(updated_X,updated_Y) = 17.4388285673030
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 31
# Step 2: slopex = 4.36387455505950 slopey = 3.27290591629462
# Step 3: delta_X -0.0436387455505950 delta_Y -0.0327290591629462
# Step 4: Updated Value X = 2.13829853197915 Y = 1.60372389898437
# Checking for the result value of the function f(updated_X,updated_Y) = 17.1442509560378
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 32
# Step 2: slopex = 4.27659706395831 slopey = 3.20744779796873
# Step 3: delta_X -0.0427659706395831 delta_Y -0.0320744779796873
# Step 4: Updated Value X = 2.09553256133957 Y = 1.57164942100468
# Checking for the result value of the function f(updated_X,updated_Y) = 16.8613386181787
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 33
# Step 2: slopex = 4.19106512267914 slopey = 3.14329884200936
# Step 3: delta_X -0.0419106512267914 delta_Y -0.0314329884200936
# Step 4: Updated Value X = 2.05362191011278 Y = 1.54021643258458
# Checking for the result value of the function f(updated_X,updated_Y) = 16.5896296088988
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 34
# Step 2: slopex = 4.10724382022556 slopey = 3.08043286516917
# Step 3: delta_X -0.0410724382022556 delta_Y -0.0308043286516917
# Step 4: Updated Value X = 2.01254947191052 Y = 1.50941210393289
# Checking for the result value of the function f(updated_X,updated_Y) = 16.3286802763865
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 35
# Step 2: slopex = 4.02509894382105 slopey = 3.01882420786579
# Step 3: delta_X -0.0402509894382105 delta_Y -0.0301882420786579
# Step 4: Updated Value X = 1.97229848247231 Y = 1.47922386185423
# Checking for the result value of the function f(updated_X,updated_Y) = 16.0780645374415
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 36
# Step 2: slopex = 3.94459696494463 slopey = 2.95844772370847
# Step 3: delta_X -0.0394459696494463 delta_Y -0.0295844772370847
# Step 4: Updated Value X = 1.93285251282287 Y = 1.44963938461715
# Checking for the result value of the function f(updated_X,updated_Y) = 15.8373731817589
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 37
# Step 2: slopex = 3.86570502564573 slopey = 2.89927876923430
# Step 3: delta_X -0.0386570502564573 delta_Y -0.0289927876923430
# Step 4: Updated Value X = 1.89419546256641 Y = 1.42064659692481
# Checking for the result value of the function f(updated_X,updated_Y) = 15.6062132037612
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 38
# Step 2: slopex = 3.78839092513282 slopey = 2.84129319384961
# Step 3: delta_X -0.0378839092513282 delta_Y -0.0284129319384961
# Step 4: Updated Value X = 1.85631155331508 Y = 1.39223366498631
# Checking for the result value of the function f(updated_X,updated_Y) = 15.3842071608923
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 39
# Step 2: slopex = 3.71262310663016 slopey = 2.78446732997262
# Step 3: delta_X -0.0371262310663016 delta_Y -0.0278446732997262
# Step 4: Updated Value X = 1.81918532224878 Y = 1.36438899168658
# Checking for the result value of the function f(updated_X,updated_Y) = 15.1709925573209
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 40
# Step 2: slopex = 3.63837064449756 slopey = 2.72877798337317
# Step 3: delta_X -0.0363837064449756 delta_Y -0.0272877798337317
# Step 4: Updated Value X = 1.78280161580380 Y = 1.33710121185285
# Checking for the result value of the function f(updated_X,updated_Y) = 14.9662212520510
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 41
# Step 2: slopex = 3.56560323160761 slopey = 2.67420242370571
# Step 3: delta_X -0.0356560323160761 delta_Y -0.0267420242370571
# Step 4: Updated Value X = 1.74714558348773 Y = 1.31035918761580
# Checking for the result value of the function f(updated_X,updated_Y) = 14.7695588904698
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 42
# Step 2: slopex = 3.49429116697546 slopey = 2.62071837523159
# Step 3: delta_X -0.0349429116697546 delta_Y -0.0262071837523159
# Step 4: Updated Value X = 1.71220267181797 Y = 1.28415200386348
# Checking for the result value of the function f(updated_X,updated_Y) = 14.5806843584072
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 43
# Step 2: slopex = 3.42440534363595 slopey = 2.56830400772696
# Step 3: delta_X -0.0342440534363595 delta_Y -0.0256830400772696
# Step 4: Updated Value X = 1.67795861838161 Y = 1.25846896378621
# Checking for the result value of the function f(updated_X,updated_Y) = 14.3992892578143
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 44
# Step 2: slopex = 3.35591723676323 slopey = 2.51693792757242
# Step 3: delta_X -0.0335591723676323 delta_Y -0.0251693792757242
# Step 4: Updated Value X = 1.64439944601398 Y = 1.23329958451049
# Checking for the result value of the function f(updated_X,updated_Y) = 14.2250774032048
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 45
# Step 2: slopex = 3.28879889202796 slopey = 2.46659916902097
# Step 3: delta_X -0.0328879889202796 delta_Y -0.0246659916902097
# Step 4: Updated Value X = 1.61151145709370 Y = 1.20863359282028
# Checking for the result value of the function f(updated_X,updated_Y) = 14.0577643380379
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 46
# Step 2: slopex = 3.22302291418740 slopey = 2.41726718564055
# Step 3: delta_X -0.0322302291418740 delta_Y -0.0241726718564055
# Step 4: Updated Value X = 1.57928122795183 Y = 1.18446092096387
# Checking for the result value of the function f(updated_X,updated_Y) = 13.8970768702516
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 47
# Step 2: slopex = 3.15856245590366 slopey = 2.36892184192774
# Step 3: delta_X -0.0315856245590366 delta_Y -0.0236892184192774
# Step 4: Updated Value X = 1.54769560339279 Y = 1.16077170254459
# Checking for the result value of the function f(updated_X,updated_Y) = 13.7427526261897
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 48
# Step 2: slopex = 3.09539120678558 slopey = 2.32154340508919
# Step 3: delta_X -0.0309539120678558 delta_Y -0.0232154340508919
# Step 4: Updated Value X = 1.51674169132494 Y = 1.13755626849370
# Checking for the result value of the function f(updated_X,updated_Y) = 13.5945396221925
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 49
# Step 2: slopex = 3.03348338264987 slopey = 2.27511253698740
# Step 3: delta_X -0.0303348338264987 delta_Y -0.0227511253698740
# Step 4: Updated Value X = 1.48640685749844 Y = 1.11480514312383
# Checking for the result value of the function f(updated_X,updated_Y) = 13.4521958531537
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 50
# Step 2: slopex = 2.97281371499687 slopey = 2.22961028624766
# Step 3: delta_X -0.0297281371499687 delta_Y -0.0222961028624766
# Step 4: Updated Value X = 1.45667872034847 Y = 1.09250904026135
# Checking for the result value of the function f(updated_X,updated_Y) = 13.3154888973688
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 51
# Step 2: slopex = 2.91335744069694 slopey = 2.18501808052270
# Step 3: delta_X -0.0291335744069694 delta_Y -0.0218501808052270
# Step 4: Updated Value X = 1.42754514594150 Y = 1.07065885945612
# Checking for the result value of the function f(updated_X,updated_Y) = 13.1841955370330
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 52
# Step 2: slopex = 2.85509029188300 slopey = 2.14131771891225
# Step 3: delta_X -0.0285509029188300 delta_Y -0.0214131771891225
# Step 4: Updated Value X = 1.39899424302267 Y = 1.04924568226700
# Checking for the result value of the function f(updated_X,updated_Y) = 13.0581013937665
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 53
# Step 2: slopex = 2.79798848604534 slopey = 2.09849136453400
# Step 3: delta_X -0.0279798848604534 delta_Y -0.0209849136453400
# Step 4: Updated Value X = 1.37101435816222 Y = 1.02826076862166
# Checking for the result value of the function f(updated_X,updated_Y) = 12.9370005785734
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 54
# Step 2: slopex = 2.74202871632443 slopey = 2.05652153724332
# Step 3: delta_X -0.0274202871632443 delta_Y -0.0205652153724332
# Step 4: Updated Value X = 1.34359407099897 Y = 1.00769555324923
# Checking for the result value of the function f(updated_X,updated_Y) = 12.8206953556619
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 55
# Step 2: slopex = 2.68718814199794 slopey = 2.01539110649846
# Step 3: delta_X -0.0268718814199794 delta_Y -0.0201539110649846
# Step 4: Updated Value X = 1.31672218957899 Y = 0.987541642184244
# Checking for the result value of the function f(updated_X,updated_Y) = 12.7089958195776
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 56
# Step 2: slopex = 2.63344437915798 slopey = 1.97508328436849
# Step 3: delta_X -0.0263344437915798 delta_Y -0.0197508328436849
# Step 4: Updated Value X = 1.29038774578741 Y = 0.967790809340559
# Checking for the result value of the function f(updated_X,updated_Y) = 12.6017195851224
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 57
# Step 2: slopex = 2.58077549157482 slopey = 1.93558161868112
# Step 3: delta_X -0.0258077549157482 delta_Y -0.0193558161868112
# Step 4: Updated Value X = 1.26457999087166 Y = 0.948434993153748
# Checking for the result value of the function f(updated_X,updated_Y) = 12.4986914895515
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 58
# Step 2: slopex = 2.52915998174333 slopey = 1.89686998630750
# Step 3: delta_X -0.0252915998174333 delta_Y -0.0189686998630750
# Step 4: Updated Value X = 1.23928839105423 Y = 0.929466293290673
# Checking for the result value of the function f(updated_X,updated_Y) = 12.3997433065653
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 59
# Step 2: slopex = 2.47857678210846 slopey = 1.85893258658135
# Step 3: delta_X -0.0247857678210846 delta_Y -0.0185893258658135
# Step 4: Updated Value X = 1.21450262323315 Y = 0.910876967424860
# Checking for the result value of the function f(updated_X,updated_Y) = 12.3047134716253
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 60
# Step 2: slopex = 2.42900524646629 slopey = 1.82175393484972
# Step 3: delta_X -0.0242900524646629 delta_Y -0.0182175393484972
# Step 4: Updated Value X = 1.19021257076848 Y = 0.892659428076363
# Checking for the result value of the function f(updated_X,updated_Y) = 12.2134468181489
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 61
# Step 2: slopex = 2.38042514153697 slopey = 1.78531885615273
# Step 3: delta_X -0.0238042514153697 delta_Y -0.0178531885615273
# Step 4: Updated Value X = 1.16640831935311 Y = 0.874806239514835
# Checking for the result value of the function f(updated_X,updated_Y) = 12.1257943241502
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 62
# Step 2: slopex = 2.33281663870623 slopey = 1.74961247902967
# Step 3: delta_X -0.0233281663870623 delta_Y -0.0174961247902967
# Step 4: Updated Value X = 1.14308015296605 Y = 0.857310114724539
# Checking for the result value of the function f(updated_X,updated_Y) = 12.0416128689139
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 63
# Step 2: slopex = 2.28616030593210 slopey = 1.71462022944908
# Step 3: delta_X -0.0228616030593210 delta_Y -0.0171462022944908
# Step 4: Updated Value X = 1.12021854990673 Y = 0.840163912430048
# Checking for the result value of the function f(updated_X,updated_Y) = 11.9607649993049
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 64
# Step 2: slopex = 2.24043709981346 slopey = 1.68032782486010
# Step 3: delta_X -0.0224043709981346 delta_Y -0.0168032782486010
# Step 4: Updated Value X = 1.09781417890860 Y = 0.823360634181447
# Checking for the result value of the function f(updated_X,updated_Y) = 11.8831187053324
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 65
# Step 2: slopex = 2.19562835781719 slopey = 1.64672126836289
# Step 3: delta_X -0.0219562835781719 delta_Y -0.0164672126836289
# Step 4: Updated Value X = 1.07585789533042 Y = 0.806893421497818
# Checking for the result value of the function f(updated_X,updated_Y) = 11.8085472046013
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 66
# Step 2: slopex = 2.15171579066085 slopey = 1.61378684299564
# Step 3: delta_X -0.0215171579066085 delta_Y -0.0161378684299564
# Step 4: Updated Value X = 1.05434073742382 Y = 0.790755553067862
# Checking for the result value of the function f(updated_X,updated_Y) = 11.7369287352991
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 67
# Step 2: slopex = 2.10868147484763 slopey = 1.58151110613572
# Step 3: delta_X -0.0210868147484763 delta_Y -0.0158151110613572
# Step 4: Updated Value X = 1.03325392267534 Y = 0.774940442006504
# Checking for the result value of the function f(updated_X,updated_Y) = 11.6681463573812
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 68
# Step 2: slopex = 2.06650784535068 slopey = 1.54988088401301
# Step 3: delta_X -0.0206650784535068 delta_Y -0.0154988088401301
# Step 4: Updated Value X = 1.01258884422183 Y = 0.759441633166374
# Checking for the result value of the function f(updated_X,updated_Y) = 11.6020877616289
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 69
# Step 2: slopex = 2.02517768844366 slopey = 1.51888326633275
# Step 3: delta_X -0.0202517768844366 delta_Y -0.0151888326633275
# Step 4: Updated Value X = 0.992337067337395 Y = 0.744252800503047
# Checking for the result value of the function f(updated_X,updated_Y) = 11.5386450862684
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 70
# Step 2: slopex = 1.98467413467479 slopey = 1.48850560100609
# Step 3: delta_X -0.0198467413467479 delta_Y -0.0148850560100609
# Step 4: Updated Value X = 0.972490325990647 Y = 0.729367744492986
# Checking for the result value of the function f(updated_X,updated_Y) = 11.4777147408522
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 71
# Step 2: slopex = 1.94498065198129 slopey = 1.45873548898597
# Step 3: delta_X -0.0194498065198129 delta_Y -0.0145873548898597
# Step 4: Updated Value X = 0.953040519470834 Y = 0.714780389603126
# Checking for the result value of the function f(updated_X,updated_Y) = 11.4191972371144
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 72
# Step 2: slopex = 1.90608103894167 slopey = 1.42956077920625
# Step 3: delta_X -0.0190608103894167 delta_Y -0.0142956077920625
# Step 4: Updated Value X = 0.933979709081418 Y = 0.700484781811064
# Checking for the result value of the function f(updated_X,updated_Y) = 11.3629970265247
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 73
# Step 2: slopex = 1.86795941816284 slopey = 1.40096956362213
# Step 3: delta_X -0.0186795941816284 delta_Y -0.0140096956362213
# Step 4: Updated Value X = 0.915300114899789 Y = 0.686475086174842
# Checking for the result value of the function f(updated_X,updated_Y) = 11.3090223442743
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 74
# Step 2: slopex = 1.83060022979958 slopey = 1.37295017234968
# Step 3: delta_X -0.0183060022979958 delta_Y -0.0137295017234968
# Step 4: Updated Value X = 0.896994112601794 Y = 0.672745584451345
# Checking for the result value of the function f(updated_X,updated_Y) = 11.2571850594411
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 75
# Step 2: slopex = 1.79398822520359 slopey = 1.34549116890269
# Step 3: delta_X -0.0179398822520359 delta_Y -0.0134549116890269
# Step 4: Updated Value X = 0.879054230349758 Y = 0.659290672762319
# Checking for the result value of the function f(updated_X,updated_Y) = 11.2074005310872
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 76
# Step 2: slopex = 1.75810846069952 slopey = 1.31858134552464
# Step 3: delta_X -0.0175810846069952 delta_Y -0.0131858134552464
# Step 4: Updated Value X = 0.861473145742763 Y = 0.646104859307072
# Checking for the result value of the function f(updated_X,updated_Y) = 11.1595874700561
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 77
# Step 2: slopex = 1.72294629148553 slopey = 1.29220971861414
# Step 3: delta_X -0.0172294629148553 delta_Y -0.0129220971861414
# Step 4: Updated Value X = 0.844243682827907 Y = 0.633182762120931
# Checking for the result value of the function f(updated_X,updated_Y) = 11.1136678062419
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 78
# Step 2: slopex = 1.68848736565581 slopey = 1.26636552424186
# Step 3: delta_X -0.0168848736565581 delta_Y -0.0126636552424186
# Step 4: Updated Value X = 0.827358809171349 Y = 0.620519106878512
# Checking for the result value of the function f(updated_X,updated_Y) = 11.0695665611147
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 79
# Step 2: slopex = 1.65471761834270 slopey = 1.24103821375702
# Step 3: delta_X -0.0165471761834270 delta_Y -0.0124103821375702
# Step 4: Updated Value X = 0.810811632987922 Y = 0.608108724740942
# Checking for the result value of the function f(updated_X,updated_Y) = 11.0272117252946
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 80
# Step 2: slopex = 1.62162326597584 slopey = 1.21621744948188
# Step 3: delta_X -0.0162162326597584 delta_Y -0.0121621744948188
# Step 4: Updated Value X = 0.794595400328164 Y = 0.595946550246123
# Checking for the result value of the function f(updated_X,updated_Y) = 10.9865341409729
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 81
# Step 2: slopex = 1.58919080065633 slopey = 1.19189310049225
# Step 3: delta_X -0.0158919080065633 delta_Y -0.0119189310049225
# Step 4: Updated Value X = 0.778703492321601 Y = 0.584027619241201
# Checking for the result value of the function f(updated_X,updated_Y) = 10.9474673889904
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 82
# Step 2: slopex = 1.55740698464320 slopey = 1.16805523848240
# Step 3: delta_X -0.0155740698464320 delta_Y -0.0116805523848240
# Step 4: Updated Value X = 0.763129422475168 Y = 0.572347066856376
# Checking for the result value of the function f(updated_X,updated_Y) = 10.9099476803864
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 83
# Step 2: slopex = 1.52625884495034 slopey = 1.14469413371275
# Step 3: delta_X -0.0152625884495034 delta_Y -0.0114469413371275
# Step 4: Updated Value X = 0.747866834025665 Y = 0.560900125519249
# Checking for the result value of the function f(updated_X,updated_Y) = 10.8739137522431
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 84
# Step 2: slopex = 1.49573366805133 slopey = 1.12180025103850
# Step 3: delta_X -0.0149573366805133 delta_Y -0.0112180025103850
# Step 4: Updated Value X = 0.732909497345152 Y = 0.549682123008864
# Checking for the result value of the function f(updated_X,updated_Y) = 10.8393067676543
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 85
# Step 2: slopex = 1.46581899469030 slopey = 1.09936424601773
# Step 3: delta_X -0.0146581899469030 delta_Y -0.0109936424601773
# Step 4: Updated Value X = 0.718251307398249 Y = 0.538688480548687
# Checking for the result value of the function f(updated_X,updated_Y) = 10.8060702196551
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 86
# Step 2: slopex = 1.43650261479650 slopey = 1.07737696109737
# Step 3: delta_X -0.0143650261479650 delta_Y -0.0107737696109737
# Step 4: Updated Value X = 0.703886281250284 Y = 0.527914710937713
# Checking for the result value of the function f(updated_X,updated_Y) = 10.7741498389568
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 87
# Step 2: slopex = 1.40777256250057 slopey = 1.05582942187543
# Step 3: delta_X -0.0140777256250057 delta_Y -0.0105582942187543
# Step 4: Updated Value X = 0.689808555625278 Y = 0.517356416718959
# Checking for the result value of the function f(updated_X,updated_Y) = 10.7434935053341
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 88
# Step 2: slopex = 1.37961711125056 slopey = 1.03471283343792
# Step 3: delta_X -0.0137961711125056 delta_Y -0.0103471283343792
# Step 4: Updated Value X = 0.676012384512773 Y = 0.507009288384580
# Checking for the result value of the function f(updated_X,updated_Y) = 10.7140511625229
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 89
# Step 2: slopex = 1.35202476902555 slopey = 1.01401857676916
# Step 3: delta_X -0.0135202476902555 delta_Y -0.0101401857676916
# Step 4: Updated Value X = 0.662492136822517 Y = 0.496869102616888
# Checking for the result value of the function f(updated_X,updated_Y) = 10.6857747364870
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 90
# Step 2: slopex = 1.32498427364503 slopey = 0.993738205233776
# Step 3: delta_X -0.0132498427364503 delta_Y -0.00993738205233776
# Step 4: Updated Value X = 0.649242294086067 Y = 0.486931720564550
# Checking for the result value of the function f(updated_X,updated_Y) = 10.6586180569221
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 91
# Step 2: slopex = 1.29848458817213 slopey = 0.973863441129101
# Step 3: delta_X -0.0129848458817213 delta_Y -0.00973863441129101
# Step 4: Updated Value X = 0.636257448204345 Y = 0.477193086153259
# Checking for the result value of the function f(updated_X,updated_Y) = 10.6325367818680
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 92
# Step 2: slopex = 1.27251489640869 slopey = 0.954386172306518
# Step 3: delta_X -0.0127251489640869 delta_Y -0.00954386172306518
# Step 4: Updated Value X = 0.623532299240258 Y = 0.467649224430194
# Checking for the result value of the function f(updated_X,updated_Y) = 10.6074883253060
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 93
# Step 2: slopex = 1.24706459848052 slopey = 0.935298448860388
# Step 3: delta_X -0.0124706459848052 delta_Y -0.00935298448860388
# Step 4: Updated Value X = 0.611061653255453 Y = 0.458296239941590
# Checking for the result value of the function f(updated_X,updated_Y) = 10.5834317876239
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 94
# Step 2: slopex = 1.22212330651091 slopey = 0.916592479883180
# Step 3: delta_X -0.0122212330651091 delta_Y -0.00916592479883180
# Step 4: Updated Value X = 0.598840420190344 Y = 0.449130315142758
# Checking for the result value of the function f(updated_X,updated_Y) = 10.5603278888340
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 95
# Step 2: slopex = 1.19768084038069 slopey = 0.898260630285517
# Step 3: delta_X -0.0119768084038069 delta_Y -0.00898260630285517
# Step 4: Updated Value X = 0.586863611786537 Y = 0.440147708839903
# Checking for the result value of the function f(updated_X,updated_Y) = 10.5381389044362
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 96
# Step 2: slopex = 1.17372722357307 slopey = 0.880295417679806
# Step 3: delta_X -0.0117372722357307 delta_Y -0.00880295417679806
# Step 4: Updated Value X = 0.575126339550807 Y = 0.431344754663105
# Checking for the result value of the function f(updated_X,updated_Y) = 10.5168286038205
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 97
# Step 2: slopex = 1.15025267910161 slopey = 0.862689509326210
# Step 3: delta_X -0.0115025267910161 delta_Y -0.00862689509326210
# Step 4: Updated Value X = 0.563623812759790 Y = 0.422717859569843
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4963621911092
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 98
# Step 2: slopex = 1.12724762551958 slopey = 0.845435719139686
# Step 3: delta_X -0.0112724762551958 delta_Y -0.00845435719139686
# Step 4: Updated Value X = 0.552351336504595 Y = 0.414263502378446
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4767062483413
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 99
# Step 2: slopex = 1.10470267300919 slopey = 0.828527004756892
# Step 3: delta_X -0.0110470267300919 delta_Y -0.00828527004756892
# Step 4: Updated Value X = 0.541304309774503 Y = 0.405978232330877
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4578286809070
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 100
# Step 2: slopex = 1.08260861954901 slopey = 0.811956464661754
# Step 3: delta_X -0.0108260861954901 delta_Y -0.00811956464661754
# Step 4: Updated Value X = 0.530478223579013 Y = 0.397858667684260
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4396986651430
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 101
# Step 2: slopex = 1.06095644715803 slopey = 0.795717335368519
# Step 3: delta_X -0.0106095644715803 delta_Y -0.00795717335368519
# Step 4: Updated Value X = 0.519868659107432 Y = 0.389901494330574
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4222865980034
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 102
# Step 2: slopex = 1.03973731821486 slopey = 0.779802988661149
# Step 3: delta_X -0.0103973731821486 delta_Y -0.00779802988661149
# Step 4: Updated Value X = 0.509471285925284 Y = 0.382103464443963
# Checking for the result value of the function f(updated_X,updated_Y) = 10.4055640487224
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 103
# Step 2: slopex = 1.01894257185057 slopey = 0.764206928887926
# Step 3: delta_X -0.0101894257185057 delta_Y -0.00764206928887926
# Step 4: Updated Value X = 0.499281860206778 Y = 0.374461395155084
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3895037123930
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 104
# Step 2: slopex = 0.998563720413556 slopey = 0.748922790310167
# Step 3: delta_X -0.00998563720413556 delta_Y -0.00748922790310167
# Step 4: Updated Value X = 0.489296223002643 Y = 0.366972167251982
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3740793653823
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 105
# Step 2: slopex = 0.978592446005285 slopey = 0.733944334503964
# Step 3: delta_X -0.00978592446005285 delta_Y -0.00733944334503964
# Step 4: Updated Value X = 0.479510298542590 Y = 0.359632723906942
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3592658225131
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 106
# Step 2: slopex = 0.959020597085179 slopey = 0.719265447813885
# Step 3: delta_X -0.00959020597085179 delta_Y -0.00719265447813885
# Step 4: Updated Value X = 0.469920092571738 Y = 0.352440069428804
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3450388959416
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 107
# Step 2: slopex = 0.939840185143476 slopey = 0.704880138857607
# Step 3: delta_X -0.00939840185143476 delta_Y -0.00704880138857607
# Step 4: Updated Value X = 0.460521690720303 Y = 0.345391268040227
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3313753556623
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 108
# Step 2: slopex = 0.921043381440606 slopey = 0.690782536080455
# Step 3: delta_X -0.00921043381440606 delta_Y -0.00690782536080455
# Step 4: Updated Value X = 0.451311256905897 Y = 0.338483442679423
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3182528915781
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 109
# Step 2: slopex = 0.902622513811794 slopey = 0.676966885358846
# Step 3: delta_X -0.00902622513811794 delta_Y -0.00676966885358846
# Step 4: Updated Value X = 0.442285031767779 Y = 0.331713773825834
# Checking for the result value of the function f(updated_X,updated_Y) = 10.3056500770716
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 110
# Step 2: slopex = 0.884570063535558 slopey = 0.663427547651669
# Step 3: delta_X -0.00884570063535558 delta_Y -0.00663427547651669
# Step 4: Updated Value X = 0.433439331132424 Y = 0.325079498349318
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2935463340196
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 111
# Step 2: slopex = 0.866878662264847 slopey = 0.650158996698636
# Step 3: delta_X -0.00866878662264847 delta_Y -0.00650158996698636
# Step 4: Updated Value X = 0.424770544509775 Y = 0.318577908382331
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2819218991924
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 112
# Step 2: slopex = 0.849541089019550 slopey = 0.637155816764663
# Step 3: delta_X -0.00849541089019550 delta_Y -0.00637155816764663
# Step 4: Updated Value X = 0.416275133619580 Y = 0.312206350214685
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2707577919844
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 113
# Step 2: slopex = 0.832550267239159 slopey = 0.624412700429370
# Step 3: delta_X -0.00832550267239159 delta_Y -0.00624412700429370
# Step 4: Updated Value X = 0.407949630947188 Y = 0.305962223210391
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2600357834218
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 114
# Step 2: slopex = 0.815899261894376 slopey = 0.611924446420782
# Step 3: delta_X -0.00815899261894376 delta_Y -0.00611924446420782
# Step 4: Updated Value X = 0.399790638328244 Y = 0.299842978746183
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2497383663983
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 115
# Step 2: slopex = 0.799581276656488 slopey = 0.599685957492367
# Step 3: delta_X -0.00799581276656488 delta_Y -0.00599685957492367
# Step 4: Updated Value X = 0.391794825561679 Y = 0.293846119171260
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2398487270889
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 116
# Step 2: slopex = 0.783589651123359 slopey = 0.587692238342519
# Step 3: delta_X -0.00783589651123359 delta_Y -0.00587692238342519
# Step 4: Updated Value X = 0.383958929050446 Y = 0.287969196787834
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2303507174962
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 117
# Step 2: slopex = 0.767917858100892 slopey = 0.575938393575669
# Step 3: delta_X -0.00767917858100892 delta_Y -0.00575938393575669
# Step 4: Updated Value X = 0.376279750469437 Y = 0.282209812852078
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2212288290833
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 118
# Step 2: slopex = 0.752559500938874 slopey = 0.564419625704155
# Step 3: delta_X -0.00752559500938874 delta_Y -0.00564419625704155
# Step 4: Updated Value X = 0.368754155460048 Y = 0.276565616595036
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2124681674516
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 119
# Step 2: slopex = 0.737508310920096 slopey = 0.553131233190072
# Step 3: delta_X -0.00737508310920096 delta_Y -0.00553131233190072
# Step 4: Updated Value X = 0.361379072350847 Y = 0.271034304263135
# Checking for the result value of the function f(updated_X,updated_Y) = 10.2040544280206
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 120
# Step 2: slopex = 0.722758144701694 slopey = 0.542068608526271
# Step 3: delta_X -0.00722758144701694 delta_Y -0.00542068608526271
# Step 4: Updated Value X = 0.354151490903830 Y = 0.265613618177873
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1959738726709
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 121
# Step 2: slopex = 0.708302981807660 slopey = 0.531227236355745
# Step 3: delta_X -0.00708302981807660 delta_Y -0.00531227236355745
# Step 4: Updated Value X = 0.347068461085754 Y = 0.260301345814315
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1882133073132
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 122
# Step 2: slopex = 0.694136922171507 slopey = 0.520602691628630
# Step 3: delta_X -0.00694136922171507 delta_Y -0.00520602691628631
# Step 4: Updated Value X = 0.340127091864038 Y = 0.255095318898029
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1807600603436
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 123
# Step 2: slopex = 0.680254183728077 slopey = 0.510190637796058
# Step 3: delta_X -0.00680254183728077 delta_Y -0.00510190637796058
# Step 4: Updated Value X = 0.333324550026758 Y = 0.249993412520068
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1736019619540
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 124
# Step 2: slopex = 0.666649100053515 slopey = 0.499986825040137
# Step 3: delta_X -0.00666649100053515 delta_Y -0.00499986825040137
# Step 4: Updated Value X = 0.326658059026223 Y = 0.244993544269667
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1667273242606
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 125
# Step 2: slopex = 0.653316118052445 slopey = 0.489987088539334
# Step 3: delta_X -0.00653316118052445 delta_Y -0.00489987088539334
# Step 4: Updated Value X = 0.320124897845698 Y = 0.240093673384274
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1601249222199
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 126
# Step 2: slopex = 0.640249795691396 slopey = 0.480187346768547
# Step 3: delta_X -0.00640249795691396 delta_Y -0.00480187346768547
# Step 4: Updated Value X = 0.313722399888784 Y = 0.235291799916588
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1537839753000
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 127
# Step 2: slopex = 0.627444799777568 slopey = 0.470583599833176
# Step 3: delta_X -0.00627444799777568 delta_Y -0.00470583599833176
# Step 4: Updated Value X = 0.307447951891008 Y = 0.230585963918256
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1476941298781
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 128
# Step 2: slopex = 0.614895903782017 slopey = 0.461171927836513
# Step 3: delta_X -0.00614895903782017 delta_Y -0.00461171927836513
# Step 4: Updated Value X = 0.301298992853188 Y = 0.225974244639891
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1418454423349
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 129
# Step 2: slopex = 0.602597985706377 slopey = 0.451948489279783
# Step 3: delta_X -0.00602597985706377 delta_Y -0.00451948489279783
# Step 4: Updated Value X = 0.295273012996125 Y = 0.221454759747093
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1362283628185
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 130
# Step 2: slopex = 0.590546025992249 slopey = 0.442909519494187
# Step 3: delta_X -0.00590546025992249 delta_Y -0.00442909519494187
# Step 4: Updated Value X = 0.289367552736202 Y = 0.217025664552152
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1308337196508
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 131
# Step 2: slopex = 0.578735105472404 slopey = 0.434051329104303
# Step 3: delta_X -0.00578735105472404 delta_Y -0.00434051329104303
# Step 4: Updated Value X = 0.283580201681478 Y = 0.212685151261109
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1256527043527
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 132
# Step 2: slopex = 0.567160403362956 slopey = 0.425370302522217
# Step 3: delta_X -0.00567160403362956 delta_Y -0.00425370302522217
# Step 4: Updated Value X = 0.277908597647848 Y = 0.208431448235886
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1206768572603
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 133
# Step 2: slopex = 0.555817195295697 slopey = 0.416862896471773
# Step 3: delta_X -0.00555817195295697 delta_Y -0.00416862896471773
# Step 4: Updated Value X = 0.272350425694891 Y = 0.204262819271169
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1158980537128
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 134
# Step 2: slopex = 0.544700851389783 slopey = 0.408525638542337
# Step 3: delta_X -0.00544700851389783 delta_Y -0.00408525638542337
# Step 4: Updated Value X = 0.266903417180994 Y = 0.200177562885745
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1113084907858
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 135
# Step 2: slopex = 0.533806834361987 slopey = 0.400355125771491
# Step 3: delta_X -0.00533806834361987 delta_Y -0.00400355125771491
# Step 4: Updated Value X = 0.261565348837374 Y = 0.196174011628030
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1069006745507
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 136
# Step 2: slopex = 0.523130697674748 slopey = 0.392348023256061
# Step 3: delta_X -0.00523130697674748 delta_Y -0.00392348023256061
# Step 4: Updated Value X = 0.256334041860626 Y = 0.192250531395470
# Checking for the result value of the function f(updated_X,updated_Y) = 10.1026674078384
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 137
# Step 2: slopex = 0.512668083721253 slopey = 0.384501062790940
# Step 3: delta_X -0.00512668083721253 delta_Y -0.00384501062790940
# Step 4: Updated Value X = 0.251207361023414 Y = 0.188405520767560
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0986017784880
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 138
# Step 2: slopex = 0.502414722046828 slopey = 0.376811041535121
# Step 3: delta_X -0.00502414722046828 delta_Y -0.00376811041535121
# Step 4: Updated Value X = 0.246183213802945 Y = 0.184637410352209
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0946971480599
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 139
# Step 2: slopex = 0.492366427605891 slopey = 0.369274820704418
# Step 3: delta_X -0.00492366427605891 delta_Y -0.00369274820704418
# Step 4: Updated Value X = 0.241259549526887 Y = 0.180944662145165
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0909471409967
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 140
# Step 2: slopex = 0.482519099053773 slopey = 0.361889324290330
# Step 3: delta_X -0.00482519099053773 delta_Y -0.00361889324290330
# Step 4: Updated Value X = 0.236434358536349 Y = 0.177325768902262
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0873456342133
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 141
# Step 2: slopex = 0.472868717072698 slopey = 0.354651537804523
# Step 3: delta_X -0.00472868717072698 delta_Y -0.00354651537804523
# Step 4: Updated Value X = 0.231705671365622 Y = 0.173779253524216
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0838867470984
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 142
# Step 2: slopex = 0.463411342731244 slopey = 0.347558507048433
# Step 3: delta_X -0.00463411342731244 delta_Y -0.00347558507048433
# Step 4: Updated Value X = 0.227071557938309 Y = 0.170303668453732
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0805648319133
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 143
# Step 2: slopex = 0.454143115876619 slopey = 0.340607336907464
# Step 3: delta_X -0.00454143115876619 delta_Y -0.00340607336907464
# Step 4: Updated Value X = 0.222530126779543 Y = 0.166897595084657
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0773744645696
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 144
# Step 2: slopex = 0.445060253559087 slopey = 0.333795190169315
# Step 3: delta_X -0.00445060253559087 delta_Y -0.00333795190169315
# Step 4: Updated Value X = 0.218079524243952 Y = 0.163559643182964
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0743104357726
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 145
# Step 2: slopex = 0.436159048487905 slopey = 0.327119286365929
# Step 3: delta_X -0.00436159048487905 delta_Y -0.00327119286365929
# Step 4: Updated Value X = 0.213717933759073 Y = 0.160288450319305
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0713677425160
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 146
# Step 2: slopex = 0.427435867518147 slopey = 0.320576900638610
# Step 3: delta_X -0.00427435867518147 delta_Y -0.00320576900638610
# Step 4: Updated Value X = 0.209443575083892 Y = 0.157082681312919
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0685415799124
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 147
# Step 2: slopex = 0.418887150167784 slopey = 0.314165362625838
# Step 3: delta_X -0.00418887150167784 delta_Y -0.00314165362625838
# Step 4: Updated Value X = 0.205254703582214 Y = 0.153941027686661
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0658273333478
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 148
# Step 2: slopex = 0.410509407164428 slopey = 0.307882055373321
# Step 3: delta_X -0.00410509407164428 delta_Y -0.00307882055373321
# Step 4: Updated Value X = 0.201149609510570 Y = 0.150862207132927
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0632205709473
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 149
# Step 2: slopex = 0.402299219021139 slopey = 0.301724414265855
# Step 3: delta_X -0.00402299219021139 delta_Y -0.00301724414265855
# Step 4: Updated Value X = 0.197126617320358 Y = 0.147844962990269
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0607170363378
# step 5: Update iteration
# Goto step 2
# -------------------------------------------------------------------
# Iteration number: 150
# Step 2: slopex = 0.394253234640717 slopey = 0.295689925980538
# Step 3: delta_X -0.00394253234640717 delta_Y -0.00295689925980538
# Step 4: Updated Value X = 0.193184084973951 Y = 0.144888063730463
# Checking for the result value of the function f(updated_X,updated_Y) = 10.0583126416988
# step 5: Update iteration
# ---------------------------------------------------------------------------
# Global Minima point obtained: after rounding to two values after decimal point
# X:  0.19
# Y:  0.14
# Optimal function value:  10.06
